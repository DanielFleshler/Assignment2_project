# %% [markdown]
# ## Assignment2 - Supervised Learning flow

# %% [markdown]
# ### Part 1 - Student details:
# * Please write the First Name and last 4 digits of the i.d. for each student. For example:
# <pre>Israel 9812</pre>

# %%
# student 1: Daniella Hen Hamou 8678
# student 2: Yaakov Vidal 3642
# student 3: Iegor Kovalov 9390 
# student 4: Evyatar Tam 4960 
# (optional) student 5: Shlomi Hemo 8792 
# (optional) student 6: Daniel Fleshler 2230

# %% [markdown]
# ## Part 2 - Experiments
# You could add as many code cells as needed

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import KFold, GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import f1_score, make_scorer
from sklearn.pipeline import Pipeline

# %%
train_csv  = "wine_train.csv"
test_csv  = "wine_test.csv"

train_path = '.' + os.sep + train_csv
test_path = '.' + os.sep + test_csv

train_data = pd.read_csv(train_path) #loading train-set 
test_data = pd.read_csv(test_path)  #loading test-set


# הצגת 5 השורות הראשונות של כל dataset
print(train_data.head())
print(test_data.head())
# Out:
#    alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0    12.08        1.83  2.32               18.5       81.0           1.60
# 1    13.58        2.58  2.69               24.5      105.0           1.55
# 2    12.37        0.94  1.36               10.6       88.0           1.98
# 3    11.82        1.72  1.88               19.5       86.0           2.50
# 4    13.16        3.57  2.15               21.0      102.0           1.50
#
#    flavanoids  nonflavanoid_phenols  proanthocyanins  color_intensity   hue  \
# 0        1.50                  0.52             1.64             2.40  1.08
# 1        0.84                  0.39             1.54             8.66  0.74
# 2        0.57                  0.28             0.42             1.95  1.05
# 3        1.64                  0.37             1.42             2.06  0.94
# 4        0.55                  0.43             1.30             4.00  0.60
#
#    od280/od315_of_diluted_wines  proline  target
# ...

# %%
# טבלאות סטטיסטיות
print(train_data.describe())
print(test_data.describe())

# וויזואליזציות
plt.hist(train_data["alcohol"])
plt.title("היסטוגרמה של עמודת alcohol ב-trainset")
plt.show()

plt.scatter(train_data["malic_acid"], train_data["color_intensity"])
plt.title("פיזור של עמודת malic_acid ביחס ל-color_intensity ב-trainset")
plt.xlabel("malic_acid")
plt.ylabel("color_intensity")
plt.show()
# Out:
#           alcohol  malic_acid         ash  alcalinity_of_ash   magnesium  \
# count  142.000000  142.000000  142.000000         142.000000  142.000000
# mean    12.997254    2.297746    2.361690          19.419718   99.943662
# std      0.789931    1.093317    0.283231           3.354815   13.683751
# min     11.410000    0.740000    1.360000          10.600000   78.000000
# 25%     12.370000    1.592500    2.222500          17.250000   88.000000
# 50%     13.050000    1.865000    2.360000          19.250000   98.000000
# 75%     13.637500    3.020000    2.557500          21.375000  108.000000
# max     14.750000    5.650000    3.230000          30.000000  151.000000
#
#        total_phenols  flavanoids  nonflavanoid_phenols  proanthocyanins  \
# count     142.000000  142.000000            142.000000       142.000000
# mean        2.315986    2.063592              0.346690         1.561901
# std         0.639469    1.005302              0.117562         0.540979
# ...

# %%
# נירמול עמודות מספריות
scaler = StandardScaler()
numeric_features = ["alcohol", "malic_acid", "ash", "alcalinity_of_ash", "magnesium",
                    "total_phenols", "flavanoids", "nonflavanoid_phenols", "proanthocyanins",
                    "color_intensity", "hue", "od280/od315_of_diluted_wines", "proline"]

train_data[numeric_features] = scaler.fit_transform(train_data[numeric_features])
test_data[numeric_features] = scaler.transform(test_data[numeric_features])

# יצירת עמודות חדשות
train_data["alcohol2"] = train_data["alcohol"] ** 2
test_data["alcohol2"] = test_data["alcohol"] ** 2

# %%
# הגדרת מודלים
model1 = LinearRegression()
model2 = LogisticRegression(max_iter=1000)
model3 = KNeighborsClassifier()

# הגדרת קיפולים צולבים
cv = KFold(n_splits=5, shuffle=True, random_state=42)

# הגדרת רשת פרמטרים עבור GridSearchCV
param_grid = [
    {
        'model': [LinearRegression()],
        'model__fit_intercept': [True, False],
        'features': [["alcohol", "alcohol2"], ["alcohol"]]
    },
    {
        'model': [LogisticRegression(max_iter=1000)],
        'model__C': [0.1, 1, 10],
        'features': [["alcohol", "alcohol2"], ["alcohol"]]
    },
    {
        'model': [KNeighborsClassifier()],
        'model__n_neighbors': [3, 5, 7],
        'features': [["alcohol", "alcohol2"], ["alcohol"]]
    }
]

# הגדרת Pipeline
for params in param_grid:
    features = params.pop('features')
    for feature_set in features:
        X_train = train_data[feature_set]
        y_train = train_data["color_intensity"]

        pipeline = Pipeline([
            ('model', params['model'][0])
        ])

        grid = GridSearchCV(pipeline, param_grid=params, cv=cv, scoring=make_scorer(r2_score if params['model'][0] == LinearRegression() else f1_score, average="macro"))

        grid.fit(X_train, y_train)

        print(f"Best parameters for features {feature_set}:")
        print(grid.best_params_)
        print("Best score:", grid.best_score_)
# Out:
# Best parameters for features ['alcohol', 'alcohol2']:
# {'model': LinearRegression(), 'model__fit_intercept': True}
# Best score: nan
# Best parameters for features ['alcohol']:
# {'model': LinearRegression(), 'model__fit_intercept': True}
# Best score: nan
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/model_selection/_validation.py:982: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/model_selection/_validation.py", line 971, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/metrics/_scorer.py", line 279, in __call__
# ...

# %%
results = []

for params in param_grid:
    features = params.pop('features')
    for feature_set in features:
        X_train = train_data[feature_set]
        y_train = train_data["color_intensity"]

        pipeline = Pipeline([
            ('model', params['model'][0])
        ])

        grid = GridSearchCV(pipeline, param_grid=params, cv=cv, scoring=make_scorer(r2_score if params['model'][0] == LinearRegression() else f1_score, average="macro"))

        grid.fit(X_train, y_train)

        results.append({
            "Model": type(params['model'][0]).__name__,
            "Feature Engineering": feature_set,
            "Best Params": grid.best_params_,
            "Best Score": grid.best_score_
        })

results_df = pd.DataFrame(results)
print(results_df)

# %% [markdown]
# ## Part 3 - Training flow
# Use the best combination of feature engineering, model (algorithm and hyperparameters) from the experiment part (part 2)
